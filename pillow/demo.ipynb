# %%
import pillow as pl
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pillow as pl
#
# ModuleNotFoundError: No module named 'pillow'

# %%
# Out:
# ...
# WARNING: Ignoring invalid distribution ~cipy (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~etworkx (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~etworkx (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (C:\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~etworkx (C:\Python311\Lib\site-packages)
